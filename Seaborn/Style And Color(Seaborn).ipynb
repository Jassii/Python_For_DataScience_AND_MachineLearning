# %% [markdown]
# # Style and Color
#
# We've shown a few times how to control figure aesthetics in seaborn, but let's now go over it formally:

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
tips = sns.load_dataset('tips')

# %% [markdown]
# ## Styles
#
# You can set particular styles:

# %%
sns.countplot(data=tips,x='sex')

# %%
sns.set_style('dark')
sns.countplot(data=tips,x='sex')

# %%
sns.set_style('darkgrid')
sns.countplot(data=tips,x='sex')

# %%
sns.set_style('ticks')
sns.countplot(data=tips,x='sex',palette='deep')

# %% [markdown]
# ## Spine Removal

# %%
sns.countplot(data=tips,x='sex')
sns.despine()

# %%
sns.countplot(data=tips,x='sex')
sns.despine(left=True)

# %% [markdown]
# You can use matplotlib's **plt.figure(figsize=(width,height))** to change the size of most seaborn plots.
#
# You can control the size and aspect ratio of most seaborn grid plots by passing in parameters: size, and aspect. For example:

# %%
plt.figure(figsize=(12,3))
sns.countplot(x='sex',data=tips)

# %%
sns.lmplot(data=tips,x='total_bill',y='tip',size=2,aspect=4)
# Out:
# C:\Users\HP\Anaconda3\lib\site-packages\seaborn\regression.py:546: UserWarning: The `size` paramter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# ## Scale and Context
#
# The set_context() allows you to override default parameters:

# %%
sns.set_context('poster',font_scale=2)
sns.countplot(x='sex',data=tips,palette='coolwarm')

# %% [markdown]
# # Great Job!
